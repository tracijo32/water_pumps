# %% [markdown]
# # Pump it up: Data Mining the Water Table
#
# Predicting the status of water pumps throughout Tanzania.
#
# A DataDriven.org competition: https://www.drivendata.org/competitions/7/pump-it-up-data-mining-the-water-table/

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
features = pd.read_csv('train_values.csv',index_col='id',parse_dates=['date_recorded'])
features.head()
# Out:
#        amount_tsh date_recorded        funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14         Roman        1390         Roman
# 8776          0.0    2013-03-06       Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25  Lottery Club         686  World vision
# 67743         0.0    2013-01-28        Unicef         263        UNICEF
# 19728         0.0    2011-07-13   Action In A           0       Artisan
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
#
#                          basin          ...          payment_type  \
# id                                      ...
# 69572               Lake Nyasa          ...              annually
# 8776             Lake Victoria          ...             never pay
# 34310                  Pangani          ...            per bucket
# 67743  Ruvuma / Southern Coast          ...             never pay
# 19728            Lake Victoria          ...             never pay
#
#       water_quality  quality_group      quantity quantity_group  \
# id
# 69572          soft           good        enough         enough
# 8776           soft           good  insufficient   insufficient
# 34310          soft           good        enough         enough
# 67743          soft           good           dry            dry
# 19728          soft           good      seasonal       seasonal
#
#                      source           source_type source_class  \
# id
# 69572                spring                spring  groundwater
# 8776   rainwater harvesting  rainwater harvesting      surface
# 34310                   dam                   dam      surface
# 67743           machine dbh              borehole  groundwater
# 19728  rainwater harvesting  rainwater harvesting      surface
#
#                    waterpoint_type waterpoint_type_group
# id
# 69572           communal standpipe    communal standpipe
# 8776            communal standpipe    communal standpipe
# 34310  communal standpipe multiple    communal standpipe
# 67743  communal standpipe multiple    communal standpipe
# 19728           communal standpipe    communal standpipe
#
# [5 rows x 39 columns]

# %%
labels = pd.read_csv('train_labels.csv',index_col='id')
labels['status_group'].value_counts()/len(labels)
# Out:
# functional                 0.543081
# non functional             0.384242
# functional needs repair    0.072677
# Name: status_group, dtype: float64

# %% [markdown]
# ### Categorical feature selection
#
# Notes on the selection of the categorical features. Many columns have redundant information and based on the number counts, certain columns are added and others are ignored.
#
# I used the method ```value_counts()``` as well as ```pd.crosstab()``` to look at the number of data points with various labels and how labels are similar/different for columns describing similar information.
#
# I will not include any of the geographic information as that is saved in the longitude and latitude categories.
#
# - ```funder```: has a lot of different values, with the highest cut being Government of Tanzania. I'm going to make a cut at 1000 in order to pick values that contain >2% of the data.
# - ```installer```: very similar to ```funder```, so I won't include it
# - ```wpt_name```: only 37k values, counts per category are way to low to be predictive
# - ```num_private```: almost all of these are 0.
# - ```public_meeting```: 85% are true, will be included as binary
# - ```recorded_by```: all are the same value, not included
# - ```scheme_management```,```scheme_name```: the first is 12 categories, an aggregation of the second. I'm going to make a cut of 1000 again as the next value down, Other, is at 766 with two more values below that, which I will effectively consider to be other.
# - ```permit```: 65% True, will include as binary
# - ```extraction_type```,```extraction_type_group```,```extraction_type_class```: each is an aggregation of the ones before. Will use ```extraction_type_class``` for now, which has 7 categories. I will only encode gravity, handpump, and submersible, effectively classifying everything else as 'other'
# - ```management```,```management_group```: the latter groups together vwc, water board, wua, and wug as user-group in the former. There are enough counts in each of these categories to justify including them as their own categories. I will set the cut at 1000 for ```management_group```, may consider using only ```management``` if need be.
# - ```payment```,```payment_type```: redundant, only choose one, with cut at 2000 to remove the other category.
# - ```water_quality```,```quality_type```: almost redundant, the latter separates fluoride and salty into separate abandoned categories. The counts in these abandoned categories is small to justify using the aggregated column, with a cut of 2000.
# - ```quantity```,```quantity_group```: redundant, cut values at 1000 to drop unknown category
# - ```source```,```source_type```,```source_class```: each column is an aggregation of the one before it. ```source_class``` only has three labels, so I'll use ```source_type``` with a cut of 2000 to drop dam and other.
# - ```waterpoint_type```,```waterpoint_type_group```: redundant, cut values at 7000 to drop cattle trough, dam, and improved spring, and other

# %%
def one_hot_encoder(df_old,df_new,column,threshold=None,values=None,name=None):
    if name is None:
        name = column
    if values is None and threshold is not None:
        f = df_old[column].value_counts()
        values = f.index[f>threshold]
    for v in values:
        df_new[name+'_'+v] = df_old[column].apply(lambda x: 1 if x == v else 0)
    return df_new

# %%
C = pd.DataFrame(index=features.index)

C = one_hot_encoder(features,C,'funder',threshold=1000)
C['public_meeting'] = features['public_meeting'].apply(lambda x: 1 if x else 0)
C = one_hot_encoder(features,C,'scheme_management',threshold=1000)
C['permit'] = features['permit'].apply(lambda x: 1 if x else 0)
C = one_hot_encoder(features,C,'extraction_type_class',values=['gravity','handpump','submersible'])
C = one_hot_encoder(features,C,'management_group',threshold=1000)
C = one_hot_encoder(features,C,'payment',threshold=2000)
C = one_hot_encoder(features,C,'quality_group',threshold=2000)
C = one_hot_encoder(features,C,'quantity',threshold=1000)
C = one_hot_encoder(features,C,'source_type',threshold=2000)
C = one_hot_encoder(features,C,'waterpoint_type',threshold=7000)
C.shape
# Out:
# (59400, 43)

# %% [markdown]
# ### Numerical feature selection
#
# Notes on numerical feature selection and transformation.
#
# - ```amount_tsh```: The variance in this column is really high, so take the logarithm and call this column ```amount_tsh_log```
# - ```gps_height```: 34% of the data are an elevation of 0, making me think that those are mainly missing values. Consider transforming this numerical feature into a categorical feature, with values low, medium, high, unknown.
# - ```longitude```,```latitude```: there are a cluster of 1800 points at (0,0), which are clearly where data are missing. I ran ```pd.crosstab()``` on the values where longitude is 0 (clearly wrong since this is not Tanzania) by ```region_code``` and ```district_code``` and found that these come from three specific region-district pairs. There are other data in these groups with latitude and longitude info, so I'll fill the missing values with the mean lat,long of the region-pair.
# - ```num_private```: 98.7% of these values are zero, so I'll ignore it.
# - ```population```: 35% of these values are zero, for now I'll ignore it. It may also be correlated with location.
# - ```construction_year```: 35% of these values are zero, so for now I'll ignore it.

# %%
N = pd.DataFrame(index=features.index)
N['amount_tsh_log'] = features['amount_tsh'].apply(lambda x: np.log(x) if x > 0 else 0)

f = features.copy()
f.loc[features['longitude'] == 0,['latitude','longitude']] = np.nan
N['latitude'] = f.groupby('region_code')['latitude'].apply(lambda x: x.fillna(np.mean(x)))
N['longitude'] = f.groupby('region_code')['longitude'].apply(lambda x: x.fillna(np.mean(x)))

# %% [markdown]
# ### Engineered features
#
# I engineered some features out of the ones that were not selected above.
#
# ```construction_decade```: changed ```construction_year``` to construction decade for all data built after 1970.
# ```month_recorded```,```year_recorded```: extracted the month and year from ```date_recorded```

# %%
E = pd.DataFrame(index=features.index)
ser=pd.cut(features['construction_year'],[0,1960,1970,1980,1990,2000,2010,2020])
counts = ser.value_counts()
values = counts[counts>2000].index
for v in values:
    name = features.loc[ser==v,'construction_year'].min().astype(str)
    E['construction_decade_'+name] = features['construction_year'].apply(lambda x: 1 if x in v else 0)
E['month_recorded'] = features['date_recorded'].apply(lambda x: x.month)
E['year_recorded'] = features['date_recorded'].apply(lambda x: x.year)

# %% [markdown]
# ### Merge features together

# %%
X = pd.merge(pd.merge(C,N,on='id'),E,on='id')
y = labels['status_group']

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,stratify=y,test_size=0.8,random_state=123)

# %%
grid = GridSearchCV(
        GradientBoostingClassifier(random_state=123,learning_rate=0.1,n_estimators=100),
        cv=3,n_jobs=6,return_train_score=False,verbose=2,
        param_grid = {'n_estimators':[100,200,300,400],
                     'min_samples_split':[2,3,4],
                     #'min_samples_leaf':[1,2,3,4],
                     'max_depth':[5,6,7,8]}
)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [CV] max_depth=5, min_samples_split=2, n_estimators=100 ..............
# [CV] max_depth=5, min_samples_split=2, n_estimators=100 ..............
# [CV] max_depth=5, min_samples_split=2, n_estimators=100 ..............
# [CV] max_depth=5, min_samples_split=2, n_estimators=200 ..............
# [CV] max_depth=5, min_samples_split=2, n_estimators=200 ..............
# [CV] max_depth=5, min_samples_split=2, n_estimators=200 ..............
# [CV]  max_depth=5, min_samples_split=2, n_estimators=100, total=  15.5s
# [CV] max_depth=5, min_samples_split=2, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_split=2, n_estimators=100, total=  15.9s
# [CV] max_depth=5, min_samples_split=2, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_split=2, n_estimators=100, total=  16.3s
# [CV] max_depth=5, min_samples_split=2, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_split=2, n_estimators=200, total=  30.1s
# [CV] max_depth=5, min_samples_split=2, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_split=2, n_estimators=200, total=  30.8s
# [CV] max_depth=5, min_samples_split=2, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_split=2, n_estimators=200, total=  31.6s
# [CV] max_depth=5, min_samples_split=2, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_split=2, n_estimators=300, total=  46.5s
# [CV]  max_depth=5, min_samples_split=2, n_estimators=300, total=  46.9s
# [CV] max_depth=5, min_samples_split=3, n_estimators=100 ..............
# [CV] max_depth=5, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=5, min_samples_split=2, n_estimators=300, total=  47.7s
# [CV] max_depth=5, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=5, min_samples_split=3, n_estimators=100, total=  17.1s
# [CV]  max_depth=5, min_samples_split=3, n_estimators=100, total=  17.5s
# [CV] max_depth=5, min_samples_split=3, n_estimators=200 ..............
# [CV] max_depth=5, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=5, min_samples_split=3, n_estimators=100, total=  17.8s
# [CV] max_depth=5, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=5, min_samples_split=2, n_estimators=400, total= 1.0min
# [CV] max_depth=5, min_samples_split=3, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_split=2, n_estimators=400, total= 1.1min
# [CV] max_depth=5, min_samples_split=3, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_split=2, n_estimators=400, total= 1.1min
# [CV] max_depth=5, min_samples_split=3, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_split=3, n_estimators=200, total=  31.3s
# [CV] max_depth=5, min_samples_split=3, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_split=3, n_estimators=200, total=  31.8s
# [CV] max_depth=5, min_samples_split=3, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_split=3, n_estimators=200, total=  32.1s
# [CV] max_depth=5, min_samples_split=3, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_split=3, n_estimators=300, total=  46.0s
# [CV] max_depth=5, min_samples_split=4, n_estimators=100 ..............
# [CV]  max_depth=5, min_samples_split=3, n_estimators=300, total=  46.3s
# [CV] max_depth=5, min_samples_split=4, n_estimators=100 ..............
# [CV]  max_depth=5, min_samples_split=3, n_estimators=300, total=  48.0s
# [CV] max_depth=5, min_samples_split=4, n_estimators=100 ..............
# [CV]  max_depth=5, min_samples_split=4, n_estimators=100, total=  16.8s
# [CV] max_depth=5, min_samples_split=4, n_estimators=200 ..............
# [CV]  max_depth=5, min_samples_split=4, n_estimators=100, total=  16.4s
# [CV] max_depth=5, min_samples_split=4, n_estimators=200 ..............
# [CV]  max_depth=5, min_samples_split=4, n_estimators=100, total=  17.1s
# [CV] max_depth=5, min_samples_split=4, n_estimators=200 ..............
# [CV]  max_depth=5, min_samples_split=3, n_estimators=400, total= 1.1min
# [CV] max_depth=5, min_samples_split=4, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_split=3, n_estimators=400, total= 1.1min
# [CV] max_depth=5, min_samples_split=4, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_split=3, n_estimators=400, total= 1.1min
# [CV] max_depth=5, min_samples_split=4, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_split=4, n_estimators=200, total=  36.8s
# [CV] max_depth=5, min_samples_split=4, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_split=4, n_estimators=200, total=  36.7s
# [CV] max_depth=5, min_samples_split=4, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_split=4, n_estimators=200, total=  36.3s
# [CV] max_depth=5, min_samples_split=4, n_estimators=400 ..............
# [Parallel(n_jobs=6)]: Done  29 tasks      | elapsed:  3.3min
# [CV]  max_depth=5, min_samples_split=4, n_estimators=300, total=  51.0s
# [CV] max_depth=6, min_samples_split=2, n_estimators=100 ..............
# [CV]  max_depth=5, min_samples_split=4, n_estimators=300, total=  51.9s
# [CV] max_depth=6, min_samples_split=2, n_estimators=100 ..............
# [CV]  max_depth=5, min_samples_split=4, n_estimators=300, total=  51.2s
# [CV] max_depth=6, min_samples_split=2, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=2, n_estimators=100, total=  26.3s
# [CV] max_depth=6, min_samples_split=2, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=2, n_estimators=100, total=  26.0s
# [CV] max_depth=6, min_samples_split=2, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=2, n_estimators=100, total=  26.8s
# [CV] max_depth=6, min_samples_split=2, n_estimators=200 ..............
# [CV]  max_depth=5, min_samples_split=4, n_estimators=400, total= 1.1min
# [CV] max_depth=6, min_samples_split=2, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_split=4, n_estimators=400, total= 1.2min
# [CV] max_depth=6, min_samples_split=2, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_split=4, n_estimators=400, total= 1.1min
# [CV] max_depth=6, min_samples_split=2, n_estimators=300 ..............
# [CV]  max_depth=6, min_samples_split=2, n_estimators=200, total=  47.1s
# [CV] max_depth=6, min_samples_split=2, n_estimators=400 ..............
# [CV]  max_depth=6, min_samples_split=2, n_estimators=200, total=  48.4s
# [CV] max_depth=6, min_samples_split=2, n_estimators=400 ..............
# [CV]  max_depth=6, min_samples_split=2, n_estimators=200, total=  48.7s
# [CV] max_depth=6, min_samples_split=2, n_estimators=400 ..............
# [CV]  max_depth=6, min_samples_split=2, n_estimators=300, total= 1.2min
# [CV] max_depth=6, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=2, n_estimators=300, total= 1.2min
# [CV] max_depth=6, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=2, n_estimators=300, total= 1.2min
# [CV] max_depth=6, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=100, total=  27.1s
# [CV] max_depth=6, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=100, total=  26.8s
# [CV] max_depth=6, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=100, total=  26.5s
# [CV] max_depth=6, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=2, n_estimators=400, total= 1.7min
# [CV] max_depth=6, min_samples_split=3, n_estimators=300 ..............
# [CV]  max_depth=6, min_samples_split=2, n_estimators=400, total= 1.7min
# [CV] max_depth=6, min_samples_split=3, n_estimators=300 ..............
# [CV]  max_depth=6, min_samples_split=2, n_estimators=400, total= 1.7min
# [CV] max_depth=6, min_samples_split=3, n_estimators=300 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=200, total=  59.3s
# [CV] max_depth=6, min_samples_split=3, n_estimators=400 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=200, total= 1.0min
# [CV] max_depth=6, min_samples_split=3, n_estimators=400 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=200, total=  59.2s
# [CV] max_depth=6, min_samples_split=3, n_estimators=400 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=300, total= 1.5min
# [CV] max_depth=6, min_samples_split=4, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=300, total= 1.5min
# [CV] max_depth=6, min_samples_split=4, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=300, total= 1.5min
# [CV] max_depth=6, min_samples_split=4, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=4, n_estimators=100, total=  31.3s
# [CV] max_depth=6, min_samples_split=4, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=4, n_estimators=100, total=  31.1s
# [CV] max_depth=6, min_samples_split=4, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=4, n_estimators=100, total=  31.9s
# [CV] max_depth=6, min_samples_split=4, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=400, total= 1.9min
# [CV] max_depth=6, min_samples_split=4, n_estimators=300 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=400, total= 1.9min
# [CV] max_depth=6, min_samples_split=4, n_estimators=300 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=400, total= 1.9min
# [CV] max_depth=6, min_samples_split=4, n_estimators=300 ..............
# [CV]  max_depth=6, min_samples_split=4, n_estimators=200, total=  54.3s
# [CV] max_depth=6, min_samples_split=4, n_estimators=400 ..............
# [CV]  max_depth=6, min_samples_split=4, n_estimators=200, total=  55.5s
# [CV] max_depth=6, min_samples_split=4, n_estimators=400 ..............
# [CV]  max_depth=6, min_samples_split=4, n_estimators=200, total=  56.7s
# [CV] max_depth=6, min_samples_split=4, n_estimators=400 ..............
# [CV]  max_depth=6, min_samples_split=4, n_estimators=300, total= 1.3min
# [CV] max_depth=7, min_samples_split=2, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=4, n_estimators=300, total= 1.4min
# [CV] max_depth=7, min_samples_split=2, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=4, n_estimators=300, total= 1.3min
# [CV] max_depth=7, min_samples_split=2, n_estimators=100 ..............
# [CV]  max_depth=7, min_samples_split=2, n_estimators=100, total=  40.3s
# [CV] max_depth=7, min_samples_split=2, n_estimators=200 ..............
# [CV]  max_depth=7, min_samples_split=2, n_estimators=100, total=  40.6s
# [CV] max_depth=7, min_samples_split=2, n_estimators=200 ..............
# [CV]  max_depth=7, min_samples_split=2, n_estimators=100, total=  39.9s
# [CV] max_depth=7, min_samples_split=2, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=4, n_estimators=400, total= 1.7min
# [CV] max_depth=7, min_samples_split=2, n_estimators=300 ..............
# [CV]  max_depth=6, min_samples_split=4, n_estimators=400, total= 1.7min
# [CV] max_depth=7, min_samples_split=2, n_estimators=300 ..............
# [CV]  max_depth=6, min_samples_split=4, n_estimators=400, total= 1.8min
# [CV] max_depth=7, min_samples_split=2, n_estimators=300 ..............
# [CV]  max_depth=7, min_samples_split=2, n_estimators=200, total= 1.1min
# [CV] max_depth=7, min_samples_split=2, n_estimators=400 ..............
# [CV]  max_depth=7, min_samples_split=2, n_estimators=200, total= 1.2min
# [CV] max_depth=7, min_samples_split=2, n_estimators=400 ..............
# [CV]  max_depth=7, min_samples_split=2, n_estimators=200, total= 1.2min
# [CV] max_depth=7, min_samples_split=2, n_estimators=400 ..............
# [CV]  max_depth=7, min_samples_split=2, n_estimators=300, total= 1.7min
# [CV] max_depth=7, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=7, min_samples_split=2, n_estimators=300, total= 1.7min
# [CV] max_depth=7, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=7, min_samples_split=2, n_estimators=300, total= 1.7min
# [CV] max_depth=7, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=7, min_samples_split=3, n_estimators=100, total=  33.7s
# [CV] max_depth=7, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=7, min_samples_split=3, n_estimators=100, total=  34.4s
# [CV] max_depth=7, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=7, min_samples_split=3, n_estimators=100, total=  33.0s
# [CV] max_depth=7, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=7, min_samples_split=2, n_estimators=400, total= 2.2min
# [CV] max_depth=7, min_samples_split=3, n_estimators=300 ..............
# [CV]  max_depth=7, min_samples_split=2, n_estimators=400, total= 2.2min
# [CV] max_depth=7, min_samples_split=3, n_estimators=300 ..............
# [CV]  max_depth=7, min_samples_split=2, n_estimators=400, total= 2.3min
# [CV] max_depth=7, min_samples_split=3, n_estimators=300 ..............
# [CV]  max_depth=7, min_samples_split=3, n_estimators=200, total= 1.1min
# [CV] max_depth=7, min_samples_split=3, n_estimators=400 ..............
# [CV]  max_depth=7, min_samples_split=3, n_estimators=200, total= 1.2min
# [CV] max_depth=7, min_samples_split=3, n_estimators=400 ..............
# [CV]  max_depth=7, min_samples_split=3, n_estimators=200, total= 1.2min
# [CV] max_depth=7, min_samples_split=3, n_estimators=400 ..............
# [CV]  max_depth=7, min_samples_split=3, n_estimators=300, total= 1.7min
# [CV] max_depth=7, min_samples_split=4, n_estimators=100 ..............
# [CV]  max_depth=7, min_samples_split=3, n_estimators=300, total= 1.7min
# [CV] max_depth=7, min_samples_split=4, n_estimators=100 ..............
# [CV]  max_depth=7, min_samples_split=3, n_estimators=300, total= 1.6min
# [CV] max_depth=7, min_samples_split=4, n_estimators=100 ..............
# [CV]  max_depth=7, min_samples_split=4, n_estimators=100, total=  38.0s
# [CV] max_depth=7, min_samples_split=4, n_estimators=200 ..............
# [CV]  max_depth=7, min_samples_split=4, n_estimators=100, total=  39.1s
# [CV] max_depth=7, min_samples_split=4, n_estimators=200 ..............
# [CV]  max_depth=7, min_samples_split=4, n_estimators=100, total=  37.5s
# [CV] max_depth=7, min_samples_split=4, n_estimators=200 ..............
# [CV]  max_depth=7, min_samples_split=3, n_estimators=400, total= 2.2min
# [CV] max_depth=7, min_samples_split=4, n_estimators=300 ..............
# [CV]  max_depth=7, min_samples_split=3, n_estimators=400, total= 2.3min
# [CV] max_depth=7, min_samples_split=4, n_estimators=300 ..............
# [CV]  max_depth=7, min_samples_split=3, n_estimators=400, total= 2.3min
# [CV] max_depth=7, min_samples_split=4, n_estimators=300 ..............
# [CV]  max_depth=7, min_samples_split=4, n_estimators=200, total= 1.2min
# [CV] max_depth=7, min_samples_split=4, n_estimators=400 ..............
# [CV]  max_depth=7, min_samples_split=4, n_estimators=200, total= 1.1min
# [CV] max_depth=7, min_samples_split=4, n_estimators=400 ..............
# [CV]  max_depth=7, min_samples_split=4, n_estimators=200, total= 1.1min
# [CV] max_depth=7, min_samples_split=4, n_estimators=400 ..............
# [CV]  max_depth=7, min_samples_split=4, n_estimators=300, total= 1.7min
# [CV] max_depth=8, min_samples_split=2, n_estimators=100 ..............
# [CV]  max_depth=7, min_samples_split=4, n_estimators=300, total= 1.7min
# [CV] max_depth=8, min_samples_split=2, n_estimators=100 ..............
# [CV]  max_depth=7, min_samples_split=4, n_estimators=300, total= 1.7min
# [CV] max_depth=8, min_samples_split=2, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=2, n_estimators=100, total=  49.8s
# [CV] max_depth=8, min_samples_split=2, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=2, n_estimators=100, total=  50.6s
# [CV] max_depth=8, min_samples_split=2, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=2, n_estimators=100, total=  51.9s
# [CV] max_depth=8, min_samples_split=2, n_estimators=200 ..............
# [CV]  max_depth=7, min_samples_split=4, n_estimators=400, total= 2.2min
# [CV] max_depth=8, min_samples_split=2, n_estimators=300 ..............
# [CV]  max_depth=7, min_samples_split=4, n_estimators=400, total= 2.2min
# [CV] max_depth=8, min_samples_split=2, n_estimators=300 ..............
# [CV]  max_depth=7, min_samples_split=4, n_estimators=400, total= 2.3min
# [CV] max_depth=8, min_samples_split=2, n_estimators=300 ..............
# [CV]  max_depth=8, min_samples_split=2, n_estimators=200, total= 1.6min
# [CV] max_depth=8, min_samples_split=2, n_estimators=400 ..............
# [CV]  max_depth=8, min_samples_split=2, n_estimators=200, total= 1.6min
# [CV] max_depth=8, min_samples_split=2, n_estimators=400 ..............
# [CV]  max_depth=8, min_samples_split=2, n_estimators=200, total= 1.6min
# [CV] max_depth=8, min_samples_split=2, n_estimators=400 ..............
# [CV]  max_depth=8, min_samples_split=2, n_estimators=300, total= 2.3min
# [CV] max_depth=8, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=2, n_estimators=300, total= 2.3min
# [CV] max_depth=8, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=2, n_estimators=300, total= 2.4min
# [CV] max_depth=8, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=100, total=  46.7s
# [CV] max_depth=8, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=100, total=  45.8s
# [CV] max_depth=8, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=100, total=  44.4s
# [CV] max_depth=8, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=2, n_estimators=400, total= 3.3min
# [CV] max_depth=8, min_samples_split=3, n_estimators=300 ..............
# [CV]  max_depth=8, min_samples_split=2, n_estimators=400, total= 3.3min
# [CV] max_depth=8, min_samples_split=3, n_estimators=300 ..............
# [CV]  max_depth=8, min_samples_split=2, n_estimators=400, total= 3.5min
# [CV] max_depth=8, min_samples_split=3, n_estimators=300 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=200, total= 1.8min
# [CV] max_depth=8, min_samples_split=3, n_estimators=400 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=200, total= 1.9min
# [CV] max_depth=8, min_samples_split=3, n_estimators=400 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=200, total= 1.9min
# [CV] max_depth=8, min_samples_split=3, n_estimators=400 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=300, total= 2.3min
# [CV] max_depth=8, min_samples_split=4, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=300, total= 2.3min
# [CV] max_depth=8, min_samples_split=4, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=300, total= 2.3min
# [CV] max_depth=8, min_samples_split=4, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=4, n_estimators=100, total=  49.3s
# [CV] max_depth=8, min_samples_split=4, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=4, n_estimators=100, total=  49.0s
# [CV] max_depth=8, min_samples_split=4, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=4, n_estimators=100, total=  46.4s
# [CV] max_depth=8, min_samples_split=4, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=400, total= 3.0min
# [CV] max_depth=8, min_samples_split=4, n_estimators=300 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=400, total= 3.0min
# [CV] max_depth=8, min_samples_split=4, n_estimators=300 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=400, total= 3.1min
# [CV] max_depth=8, min_samples_split=4, n_estimators=300 ..............
# [CV]  max_depth=8, min_samples_split=4, n_estimators=200, total= 1.4min
# [CV] max_depth=8, min_samples_split=4, n_estimators=400 ..............
# [CV]  max_depth=8, min_samples_split=4, n_estimators=200, total= 1.4min
# [CV] max_depth=8, min_samples_split=4, n_estimators=400 ..............
# [CV]  max_depth=8, min_samples_split=4, n_estimators=200, total= 1.5min
# [CV] max_depth=8, min_samples_split=4, n_estimators=400 ..............
# [CV]  max_depth=8, min_samples_split=4, n_estimators=300, total= 2.1min
# [CV]  max_depth=8, min_samples_split=4, n_estimators=300, total= 2.1min
# [CV]  max_depth=8, min_samples_split=4, n_estimators=300, total= 2.2min
# [CV]  max_depth=8, min_samples_split=4, n_estimators=400, total= 2.1min
# [CV]  max_depth=8, min_samples_split=4, n_estimators=400, total= 2.1min
# [CV]  max_depth=8, min_samples_split=4, n_estimators=400, total= 2.2min
# [Parallel(n_jobs=6)]: Done 144 out of 144 | elapsed: 31.3min finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=123, subsample=1.0, verbose=0,
#               warm_start=False),
#        fit_params=None, iid=True, n_jobs=6,
#        param_grid={'n_estimators': [100, 200, 300, 400], 'min_samples_split': [2, 3, 4], 'max_depth': [5, 6, 7, 8]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#        scoring=None, verbose=2)

# %%
clf = grid.best_estimator_
print(grid.best_params_)
print('train score: %0.3f' % clf.score(X_train,y_train))
print('test score:  %0.3f' % clf.score(X_test,y_test))
# Out:
# {'max_depth': 7, 'min_samples_split': 4, 'n_estimators': 100}
# train score: 0.890
# test score:  0.765

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(10,10))
pd.DataFrame(clf.feature_importances_,index=X.columns).plot(kind='barh',ax=ax)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,stratify=y,test_size=0.2,random_state=123)
clf = GradientBoostingClassifier(random_state=123,learning_rate=0.1,n_estimators=100,min_samples_split=4,max_depth=7)
clf.fit(X_train,y_train)
print('train score: %0.3f' % clf.score(X_train,y_train))
print('test score:  %0.3f' % clf.score(X_test,y_test))
# Out:
# train score: 0.831
# test score:  0.785

# %%
X.columns[36:46]
# Out:
# Index(['source_type_spring', 'source_type_shallow well',
#        'source_type_borehole', 'source_type_river/lake',
#        'source_type_rainwater harvesting',
#        'waterpoint_type_communal standpipe', 'waterpoint_type_hand pump',
#        'amount_tsh_log', 'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# ## Import submission data

# %%
feat_sub = pd.read_csv('test_values.csv',index_col='id',parse_dates=['date_recorded'])
feat_sub.shape
# Out:
# (14850, 39)

# %%
Z = pd.DataFrame(index=feat_sub.index)

Z = one_hot_encoder(feat_sub,Z,'funder',values=['Government of Tanzania','Danida',
                                                'Hesawa','Rwssp','World Bank','Kkkt',
                                               'World_Vision','Unicef'])
Z['public_meeting'] = feat_sub['public_meeting'].apply(lambda x: 1 if x else 0)
Z = one_hot_encoder(feat_sub,Z,'scheme_management',values=['VWC','WUG','Water authority','WUA','Water Board',
                                                          'Parastatal','Private operator','Company'])
Z['permit'] = feat_sub['permit'].apply(lambda x: 1 if x else 0)
Z = one_hot_encoder(feat_sub,Z,'extraction_type_class',values=['gravity','handpump','submersible'])
Z = one_hot_encoder(feat_sub,Z,'management_group',values=['user-group','commercial','parastatal'])
Z = one_hot_encoder(feat_sub,Z,'payment',values=['never pay','pay per bucket','pay monthly','unknown',
                                                   'pay when scheme fails','pay annually'])
Z = one_hot_encoder(feat_sub,Z,'quality_group',values=['good','salty'])
Z = one_hot_encoder(feat_sub,Z,'quantity',values=['enough','insufficient','dry','seasonal'])
Z = one_hot_encoder(feat_sub,Z,'source_type',values=['spring','shallow well','borehole','river/lake',
                                                    'rainwater harvesting'])
Z = one_hot_encoder(feat_sub,Z,'waterpoint_type',values=['communal standpipe','hand pump'])

Z['amount_tsh_log'] = feat_sub['amount_tsh'].apply(lambda x: np.log(x) if x > 0 else 0)

feat_sub.loc[feat_sub['longitude'] == 0,['latitude','longitude']] = np.nan
Z['latitude'] = feat_sub.groupby('region_code')['latitude'].apply(lambda x: x.fillna(np.mean(x)))
Z['longitude'] = feat_sub.groupby('region_code')['longitude'].apply(lambda x: x.fillna(np.mean(x)))

ser=pd.cut(feat_sub['construction_year'],[1970,1980,1990,2000,2010,2020])
counts = ser.value_counts()
values = counts.index
for v in values:
    name = feat_sub.loc[ser==v,'construction_year'].min().astype(str)
    Z['construction_decade_'+name] = feat_sub['construction_year'].apply(lambda x: 1 if x in v else 0)
Z['month_recorded'] = feat_sub['date_recorded'].apply(lambda x: x.month)
Z['year_recorded'] = feat_sub['date_recorded'].apply(lambda x: x.year)
Z.shape
# Out:
# (14850, 53)

# %%
pred = clf.predict(Z)
submission = pd.DataFrame(pred,index=Z.index,columns=labels.columns)
submission.head()
# Out:
#          status_group
# id
# 50785      functional
# 51630      functional
# 17168      functional
# 45559  non functional
# 49871      functional

# %%
submission.to_csv('gbc_feat53.csv')

# %%
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)

# %%
i_train = y_pred_train != y_train
i_test = y_pred_test != y_test

# %%
f=features.loc[i_train[i_train].index]
f.iloc[:10].head()
# Out:
#        amount_tsh date_recorded             funder  gps_height  \
# id
# 48123         0.0    2011-08-11                Dwe         841
# 35642         0.0    2013-03-19                Adb        1198
# 55871         0.0    2012-10-17  Ministry Of Water        1327
# 62407         0.0    2011-08-01                 Bs           0
# 16232         0.0    2013-01-20                Ola           0
#
#                installer  longitude      latitude            wpt_name  \
# id
# 48123                DWE  31.772707 -7.804412e+00  Shule Ya Mtowisa A
# 35642  JANDU PLUMBER  CO  36.331608 -2.854149e+00            Kwa Luka
# 55871     Wizara ya maji  34.224798 -1.245653e+00  Kwa Bernard Odendo
# 62407                 KA  31.592379 -1.626524e+00              Bubuya
# 16232                OLA   0.000000 -2.000000e-08            Mwamunhu
#
#        num_private          basin          ...          payment_type  \
# id                                         ...
# 48123            0     Lake Rukwa          ...             never pay
# 35642            0       Internal          ...            on failure
# 55871            0  Lake Victoria          ...               unknown
# 62407            0  Lake Victoria          ...             never pay
# 16232            0  Lake Victoria          ...             never pay
#
#       water_quality  quality_group  quantity quantity_group        source  \
# id
# 48123          soft           good    enough         enough         river
# 35642          soft           good    enough         enough         river
# 55871          soft           good    enough         enough         river
# 62407          soft           good    enough         enough        spring
# 16232          soft           good    enough         enough  shallow well
#
#         source_type source_class              waterpoint_type  \
# id
# 48123    river/lake      surface           communal standpipe
# 35642    river/lake      surface           communal standpipe
# 55871    river/lake      surface  communal standpipe multiple
# 62407        spring  groundwater              improved spring
# 16232  shallow well  groundwater                    hand pump
#
#       waterpoint_type_group
# id
# 48123    communal standpipe
# 35642    communal standpipe
# 55871    communal standpipe
# 62407       improved spring
# 16232             hand pump
#
# [5 rows x 39 columns]

# %%
features.describe()
# Out:
#           amount_tsh    gps_height     longitude      latitude   num_private  \
# count   59400.000000  59400.000000  59400.000000  5.940000e+04  59400.000000
# mean      317.650385    668.297239     34.077427 -5.706033e+00      0.474141
# std      2997.574558    693.116350      6.567432  2.946019e+00     12.236230
# min         0.000000    -90.000000      0.000000 -1.164944e+01      0.000000
# 25%         0.000000      0.000000     33.090347 -8.540621e+00      0.000000
# 50%         0.000000    369.000000     34.908743 -5.021597e+00      0.000000
# 75%        20.000000   1319.250000     37.178387 -3.326156e+00      0.000000
# max    350000.000000   2770.000000     40.345193 -2.000000e-08   1776.000000
#
#         region_code  district_code    population  construction_year
# count  59400.000000   59400.000000  59400.000000       59400.000000
# mean      15.297003       5.629747    179.909983        1300.652475
# std       17.587406       9.633649    471.482176         951.620547
# min        1.000000       0.000000      0.000000           0.000000
# 25%        5.000000       2.000000      0.000000           0.000000
# 50%       12.000000       3.000000     25.000000        1986.000000
# 75%       17.000000       5.000000    215.000000        2004.000000
# max       99.000000      80.000000  30500.000000        2013.000000

# %%
pd.Series(y_pred_test[i_test]).value_counts()/len(i_test)
# Out:
# functional                 0.152694
# non functional             0.053704
# functional needs repair    0.008249
# dtype: float64

# %%
pd.Series(y_pred_test).value_counts()/len(y_pred_test)
# Out:
# functional                 0.648906
# non functional             0.326852
# functional needs repair    0.024242
# dtype: float64

# %%
pd.Series(y_train).value_counts()/len(y_train)
# Out:
# functional                 0.543077
# non functional             0.384238
# functional needs repair    0.072685
# Name: status_group, dtype: float64

# %%
pd.Series(y_test).value_counts()/len(y_test)
# Out:
# functional                 0.543098
# non functional             0.384259
# functional needs repair    0.072643
# Name: status_group, dtype: float64
